# %% [markdown]
# <a href="https://colab.research.google.com/github/sudharshan256/Beginner-PYTHON-projects/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision torchaudio tqdm

# %%
# Create necessary project folders
import os
os.makedirs('models', exist_ok=True)
os.makedirs('outputs', exist_ok=True)
os.makedirs('results', exist_ok=True)

print("Project structure created: /models, /outputs, /results")
# Out:
# Project structure created: /models, /outputs, /results

# %%
# This runs your conditional training script.
# It will automatically use the GPU ('cuda') now that you enabled it.
# !python train_conditional.py
# Out:
# ...
# CONDITIONAL GAN TRAINING
# ...
# Device: cuda
# Classes: 26 (A-Z)
# Epochs: 30
# ...
#
# 📥 Loading EMNIST dataset...
# 100% 562M/562M [00:01<00:00, 323MB/s]
# ✅ Dataset ready: 124800 images
#
# 🔧 Initializing conditional models...
# ✅ Conditional models ready!
#
# 🚀 Starting conditional training...
# This will take approximately 2-3 hours
#
# 📊 Epoch 1/30
# Training: 100% 975/975 [00:51<00:00, 18.88it/s, D_loss=1.0879, G_loss=1.1920]
# 💾 Saving conditional samples for epoch 1...
#
# 📊 Epoch 2/30
# Training: 100% 975/975 [00:50<00:00, 19.27it/s, D_loss=0.9055, G_loss=1.2589]
# 💾 Saving conditional samples for epoch 2...
#
# 📊 Epoch 3/30
# Training: 100% 975/975 [00:51<00:00, 19.12it/s, D_loss=0.6837, G_loss=1.9515]
# 💾 Saving conditional samples for epoch 3...
#
# 📊 Epoch 4/30
# Training: 100% 975/975 [00:50<00:00, 19.16it/s, D_loss=0.7739, G_loss=3.3058]
# 💾 Saving conditional samples for epoch 4...
#
# 📊 Epoch 5/30
# Training: 100% 975/975 [00:50<00:00, 19.46it/s, D_loss=0.7554, G_loss=1.5517]
# ...

# %%
# This generates your comparison images for the report.
# !python generate_results.py
# Out:
# ...
# CONDITIONAL GAN TRAINING
# ...
# Device: cuda
# Classes: 26 (A-Z)
# Epochs: 30
# ...
#
# 📥 Loading EMNIST dataset...
# ✅ Dataset ready: 124800 images
#
# 🔧 Initializing conditional models...
# ✅ Conditional models ready!
#
# 🚀 Starting conditional training...
# This will take approximately 2-3 hours
#
# 📊 Epoch 1/30
# Training: 100% 975/975 [00:51<00:00, 19.04it/s, D_loss=1.0929, G_loss=1.1328]
# 💾 Saving conditional samples for epoch 1...
#
# 📊 Epoch 2/30
# Training: 100% 975/975 [00:50<00:00, 19.22it/s, D_loss=1.1802, G_loss=1.0842]
# 💾 Saving conditional samples for epoch 2...
#
# 📊 Epoch 3/30
# Training: 100% 975/975 [00:50<00:00, 19.25it/s, D_loss=0.9931, G_loss=1.3255]
# 💾 Saving conditional samples for epoch 3...
#
# 📊 Epoch 4/30
# Training: 100% 975/975 [00:50<00:00, 19.16it/s, D_loss=0.7829, G_loss=1.3405]
# 💾 Saving conditional samples for epoch 4...
#
# 📊 Epoch 5/30
# Training: 100% 975/975 [00:50<00:00, 19.27it/s, D_loss=1.0735, G_loss=1.2458]
# ...

# %%
# Zips the 'results' folder into a file named 'final_results.zip'
# !zip -r final_results.zip results/
# Downloads the created zip file to your local computer
from google.colab import files
files.download('final_results.zip')
# Out:
#   adding: results/ (stored 0%)
#   adding: results/variations_letter_B.png (deflated 16%)
#   adding: results/complete_alphabet.png (deflated 15%)
#   adding: results/interpolation_A.png (deflated 16%)
#   adding: results/variations_letter_C.png (deflated 15%)
#   adding: results/variations_letter_Z.png (deflated 16%)
#   adding: results/variations_letter_H.png (deflated 16%)
#   adding: results/variations_letter_A.png (deflated 15%)
#   adding: results/real_vs_generated.png (deflated 27%)
#   adding: results/interpolation_Z.png (deflated 16%)
#   adding: results/interpolation_M.png (deflated 17%)
#   adding: results/summary.txt (deflated 35%)
#   adding: results/variations_letter_O.png (deflated 14%)

# %%
# Zips the 'outputs' folder into a file named 'all_epochs.zip'
# !zip -r all_epochs.zip outputs/
# Downloads the created zip file to your local computer
from google.colab import files
files.download('all_epochs.zip')
# Out:
#   adding: outputs/ (stored 0%)
#   adding: outputs/conditional_epoch_07.png (deflated 5%)
#   adding: outputs/conditional_epoch_06.png (deflated 5%)
#   adding: outputs/conditional_epoch_30.png (deflated 4%)
#   adding: outputs/conditional_epoch_22.png (deflated 5%)
#   adding: outputs/conditional_epoch_23.png (deflated 5%)
#   adding: outputs/conditional_epoch_08.png (deflated 5%)
#   adding: outputs/conditional_epoch_14.png (deflated 5%)
#   adding: outputs/conditional_epoch_15.png (deflated 5%)
#   adding: outputs/conditional_epoch_16.png (deflated 5%)
#   adding: outputs/conditional_epoch_19.png (deflated 4%)
#   adding: outputs/conditional_epoch_10.png (deflated 5%)
#   adding: outputs/conditional_epoch_20.png (deflated 5%)
#   adding: outputs/conditional_epoch_25.png (deflated 5%)
#   adding: outputs/conditional_epoch_29.png (deflated 4%)
#   adding: outputs/conditional_epoch_05.png (deflated 5%)
#   adding: outputs/conditional_epoch_18.png (deflated 4%)
# ...
